# %% [markdown]
# #  My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### **German Rodriguez**
# #### I would like to work in a Data Analytics position

# %% [markdown]
# #### *I am interested in Data Science because it lets me work from home, have decent earnings and get analyse situations through data*

# %% [markdown]
# ### The following code is a division:

# %%
1/2
# Out:
# 0.5

# %% [markdown]
# | Name | Last Name|
# |------|-----------|
# | German | Rodriguez |
# | Ivana | Tovar|
# | Dennis | Wright |

# %% [markdown]
# - German Rodriguez
# 1. Ivana Tovar
#
# ![Snowfall.jpeg](attachment:2dd07af6-95ed-4e86-8d7d-13e7b1285c5b.jpeg)
